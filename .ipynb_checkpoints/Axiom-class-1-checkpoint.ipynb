# %% [markdown]
# # # CHAPTER - 1         PRINT STATEMENT

# %%
print('Hello, World') # shift+tab (signature)
# Out:
# Hello, World

# %%
print("Aquib's, World")
# Out:
# Aquib's, World

# %%
print(1,2,3,4,"aquib",sep="---")
# Out:
# 1---2---3---4---aquib

# %%
print(1,2,3,4,"Aquib")
# Out:
# 1 2 3 4 Aquib

# %%
print("Isl","karachi",sep=",",end="\n")
print("Apple","Orange", end="\t")
print("reddish","brinjal")
# Out:
# Isl,karachi
# Apple Orange	reddish brinjal

# %%
print("Isl","karachi",sep=",",end="\t") 
print("Apple","Orange")
# Out:
# Isl,karachi	Apple Orange

# %%
'''loremfmkk j defj jfl la kfj ljflkajflka'''
print("hello")
# Out:
# hello

# %% [markdown]
# # CHAPTER-2           VARIABLES FOR STRING

# %%
name = "Imran Khan"       #variables can be changed 
name ='Imran Khan'
print(name)
# Out:
# Imran Khan

# %%
f_name = 'Imran Khan'
f_name = 'Nawaz Shareef'
print(f_name)
# Out:
# Nawaz Shareef

# %%
# int value           #It is called decleration
# value 200           # Initialization
# int value 200       #ctrl+forward slash(/) for multiple comments after selecting all
# Out:
# 'this is my computer'

# %%
value=100
type(value)
# Out:
# int

# %%
no_1=input("Enter an integer=")          # input is always string
no_2=input('Input an integer value=')
print(no_1+no_2)                 #this is a string
type(no_1)
# Out:
# Enter an integer=12
# Input an integer value=10
# 1210
# str

# %%
no_1=input("Enter an integer=")       
no_2=input('Input an integer value=')
print(int(no_1)+int(no_2))          #making it an integer, this called Type casting
type(no_1)
# Out:
# Enter an integer=12
# Input an integer value=10
# 22
# str

# %%
no_1=int(input("Enter an integer="))       
no_2=int(input('Input an integer value='))
print((no_1)+(no_2))          #making it an integer, this called 'Type casting'
type(no_1)
# Out:
# Enter an integer=12
# Input an integer value=10
# 22
# int

# %%
no_1=int(input("Enter an integer="))         #type defined is integer and input is a string"apple" that is why error generating.
no_2=int(input('Input an integer value='))
print((no_1)+(no_2))        
type(no_1)
# Out:
# Enter an integer=apple
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-9169f6274fc1> in <module>
# ----> 1 no_1=int(input("Enter an integer="))
#       2 no_2=int(input('Input an integer value='))
#       3 print((no_1)+(no_2))
#       4 type(no_1)
#
# ValueError: invalid literal for int() with base 10: 'apple'

# %%
new_name = 'Imran Khan'

# %%
name = 'Nawaz Shareef'

# %%
lesson_to_learn = 'Imran khan'
my_NAME_in_capital_letters = 'UNITED STATE AMERICA'

# %%
x , y , z = 'hello friends' , 'take tea' , 'to be honnest'

# %% [markdown]
#  # CHAPTER-3        VARIABLES FOR NUMBERS

# %%
age = 25

# %%
weight = '25'

# %%
mangoes = 10

# %%
mangoes + 10
mangoes_sum = mangoes +10

# %%
height = 25
width = 50
summation = height + width
print(height + width)
# Out:
# 75

# %%
a = 10
b = 10.5
sum = a-b
print(sum)
print(type(a))
print(type(b))

b = a
print(b)
type(b)
# Out:
# -0.5
# <class 'int'>
# <class 'float'>
# 10
# int

# %%
first_prime_num = '2'
first_odd_num = '1'
take_sum = first_prime_num + first_odd_num
print(take_sum)
type(take_sum)
print(take_sum + str(10))
# Out:
# 21
# 2110

# %% [markdown]
# # # CHAPETR - 4 MATHS EXPRESSION - FAMILIAR OPERATORS

# %%
popular_number = 4

# %%
popular_number = 2 + 2 
popular_number
# Out:
# 4

# %%
loss = 12 - 10
loss
# Out:
# 2

# %%
doxens = 3 * 12
doxens
# Out:
# 36

# %%
marks = 0
a = 5 
b = 4
marks = a/b
print(marks)        #by default divion is 'float'
print(int(marks))
# Out:
# 1.25
# 1

# %%
marks = 0
a = 5 
b = 4
marks = a//b        #giving the only integer part ignoring float part by "//"
print(marks)
# Out:
# 1

# %% [markdown]
# # Chapter -5 Variable Names Legal and Illegal

# %%
1st class = "10 Chapters" #illegal varibale name starting with starting number and space
# Out:
#   File "<ipython-input-102-e6bbf439725f>", line 1
#     1st class = "10 Chapters" #illegal varibale name starting with starting number and space
#       ^
# SyntaxError: invalid syntax

# %%
class_1st = "10 chapters" #legal variable name with number in between and underscores

# %%
class-1st = "10 chapters" #illegal variable name with "hypen(-)"
# Out:
#   File "<ipython-input-44-fcf717d4dfe9>", line 1
#     class-1st = "10 chapters" #legal variable name with number in between and underscores
#          ^
# SyntaxError: invalid syntax

# %%
and= "Aquib"        #special python words(and,print....) can not be used
# Out:
#   File "<ipython-input-52-2366afb5c549>", line 1
#     and= "Aquib"        #special python words can not be used
#       ^
# SyntaxError: invalid syntax

# %%
myFisrtName="Aquib"     #camel casing

# %% [markdown]
# # Chapter - 6 Math expressions: Unfamiliar operators

# %%
whats_left_over = 10 % 3    # "%" modula or remainder of a number
whats_left_over
# Out:
# 1

# %%
whats_left_over = 9 % 3
whats_left_over
# Out:
# 0

# %%
age = 54
age += 1
print(age)
# Out:
# 55

# %%
age = 12
age += 50
print(age)
# Out:
# 62

# %%
age = 12
age -= 2
print(age)
# Out:
# 10

# %%
age = 12
age *= 3
print(age)
# Out:
# 36

# %%
age = 12
amount_to_increment = 3
age += amount_to_increment
print(age)
# Out:
# 15

# %% [markdown]
# # Chapter - 7 Math expressions: Eliminating ambiguity

# %%
total_cost = 1 + 3 * 4
total_cost
# Out:
# 13

# %%
total_cost = (1 + 3) * 4
total_cost
# Out:
# 16

# %%
2**6   #"**" two asteric are used for exponent e.g "2 to the power 6 "
# Out:
# 64

# %%
result_of_computation = (2 * 4) * 4 + 2
result_of_computation
# Out:
# 34

# %%
result_of_computation = ((2 * 4) * 4) + 2
result_of_computation
# Out:
# 34

# %%
result_of_computation = (2 * 4) * (4 + 2)
result_of_computation
# Out:
# 48

# %%
solve= 2+3*5
solve
# Out:
# 17.0

# %%
solve=1/2 + 3//3 + 4**2        # BODMAS Rule 
solve
# Out:
# 17.5

# %%
x= "apple"
y= "banana"
print(x,y)
# Out:
# apple banana

# %%
x= "apple"
y="banana"
print(x+y)           #concatenate
# Out:
# applebanana

# %% [markdown]
# # Chapter 9 - if statements

# %%
species="dog"
if species == "cat":
    print("Yep, it's cat.")

# %%
species = "cat"
if species == "cat":
    print("Yep, it's cat.")
# Out:
# Yep, it's cat.

# %%
if species == "cat":
    status = "ok"
    kingdom = "animal"
    print("Yep, it's cat.")
# Out:
# Yep, it's cat.

# %%
if 2 + 5 == 7:
    print("Everything makes sense.")
# Out:
# Everything makes sense.

# %%
number_of_wives = 1
if number_of_wives == 1:
    print("So far so good.")
    print("Yuppy!.")
# Out:
# So far so good.
# Yuppy!.

# %%
number_of_wives=3
if number_of_wives == 4:
    print("So far so good.")
    print("Congratulations.")
print("All done")
# Out:
# All done

# %%
if 2+2 == 4:
    print("Sum is right")
# Out:
# Sum is right

# %%
no = int(input("enter first number:"))
if no % 2 == 0:
    print("The number is even")
else:
    print("The number is odd ")
# Out:
# enter first number:2
# The number is even

# %%
no= int(input("enter the number:"))
if no % 2 == 0:
    print("The number" , str(no) , "is even")
else:
    print("The number" , str(no) ,"is odd ")
# Out:
# enter the number:12
# The number 12 is even

# %% [markdown]
# # Chapter 10 - Comparison operators

# %%
car = 'audi'
car.upper() == 'AUDI'

# %%
car = "Bentley"
if car == "Bentley":
    print("Buy the Car")
# Out:
# Buy the Car

# %%
color = "Red"
if color == "Blue":
    print("Fill the color")

# %%
channel = "Cartoon Network"
if channel != "ten sports":
    print("Let's Watch")
# Out:
# Let's Watch

# %%
sum = 4
if sum == 2+2:
    print("The Sum is correct ")
# Out:
# The Sum is correct
